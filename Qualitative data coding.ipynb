# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/niveditaarvind/Documents/Qualitative Data 570.csv')
df.head()
# Out:
#    ID What is not working well and how can we do better?  \
# 0   1                                                NaN
# 1   2                                                NaN
# 2   3  I think this is already being addressed, but t...
# 3   4  I think everything is working pretty well give...
# 4   5  My team needs more time to plan/organize and h...
#
#   What is working well that we need to make sure to keep doing?  Unnamed: 3  \
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# 2  the company continues to provide reps with val...                    NaN
# 3  Keep being highly dedicated to patients and pr...                    NaN
# 4  the company hires well - I really enjoy workin...                    NaN
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
df_test = df[{'ID','What is not working well and how can we do better?','What is working well that we need to make sure to keep doing?',}]
df_test.head()
# Out:
#   What is working well that we need to make sure to keep doing?  \
# 0                                                NaN
# 1                                                NaN
# 2  the company continues to provide reps with val...
# 3  Keep being highly dedicated to patients and pr...
# 4  the company hires well - I really enjoy workin...
#
#   What is not working well and how can we do better?  ID
# 0                                                NaN   1
# 1                                                NaN   2
# 2  I think this is already being addressed, but t...   3
# 3  I think everything is working pretty well give...   4
# 4  My team needs more time to plan/organize and h...   5

# %%
import numpy as np
stress = np.column_stack([df_test[col].astype(str).str.contains("stress", na=False) for col in df_test])
stress= df_test.loc[stress.any(axis=1)]
stress
# Out:
#      What is working well that we need to make sure to keep doing?  \
# 99    We are doing a lot of things right! I love the...
# 138   I'm relatively new to the company and I've com...
# 167   Even just hearing that the company is trying t...
# 177   Executive communication is raw, honest, and so...
# 207                                                 NaN
# 211   Post work yoga sessions really help to decompr...
# 215                                                 NaN
# 325                                                 NaN
# 343   We have continued to whether the COVID storm w...
# 537   Staying interactive. the company gives there e...
# 733   I really appreciate the meeting pulses and the...
# 742   the company is clearly putting in a ton of eff...
# 1004  I'm glad to see the product dev process change...
# 1194  Continue to educate and reenforce the culture ...
# 1288  constantly growing, developing, changing, and ...
# 1366  I think the company is really trying to suppor...
# ...

# %%
import numpy as np
relationship = np.column_stack([df_test[col].astype(str).str.contains("relationship", na=False) for col in df_test])
relationship=df_test.loc[relationship.any(axis=1)]
relationship
# Out:
#      What is working well that we need to make sure to keep doing?  \
# 407   the company is open and transparent with the o...
# 902   I feel like the check in meetings are a nice w...
# 958   The open and honest transparency of new endeav...
# 1204  Motivating employees and keeping client relati...
#
#      What is not working well and how can we do better?    ID
# 407   I think salary cuts were hard and then decreas...   408
# 902                                                 NaN   903
# 958   I feel that more can be put into making sure t...   959
# 1204  Client access is not the easiest and every par...  1205

# %%
pressure = np.column_stack([df_test[col].astype(str).str.contains("pressure", na=False) for col in df_test])
pressure=df_test.loc[pressure.any(axis=1)]
pressure
# Out:
#      What is working well that we need to make sure to keep doing?  \
# 104                                                 NaN
# 539   I think encouraging conversations in difficult...
# 568   the company's culture remains great. It feels ...
# 945   Continue to communicate to the RM's what new p...
# 1022  I have been deeply impressed by the speed and ...
# 1186                                Keep communicating!
#
#      What is not working well and how can we do better?    ID
# 104   Rapid release of products and large scale offe...   105
# 539   Communication about and suggestion for working...   540
# 568   While I appreciate that the company is aggress...   569
# 945   Be mindful of the "pressure" applied to RM's d...   946
# 1022  There has been a lot of talk about hiring addi...  1023
# 1186  There are definite morale issues on some teams...  1187

# %%
communication = np.column_stack([df_test[col].astype(str).str.contains("communication", na=False) for col in df_test])
communication= df_test.loc[communication.any(axis=1)]
communication
# Out:
#      What is working well that we need to make sure to keep doing?  \
# 19    CRMs doing a great job, interfacing with impor...
# 20          Communication, communication, transparency.
# 22    There has been a noticeable positive change in...
# 30    Training and weekly updates. outstanding commu...
# 37    We are doing a wonderful job and staying compe...
# ...                                                 ...
# 1331  open communication and pulse and all hands mee...
# 1343  Support from co-workers and communication from...
# 1348  I am lucky to have a supportive team and lead,...
# 1384            continue to place patients at the front
# 1385                       Company wide communications.
#
#      What is not working well and how can we do better?    ID
# 19    Continuous customer service issues, EMR interf...    20
# 20    For re-orgs, there needs to be more support/gu...    21
# 22                                                  NaN    23
# ...

# %%
morale = np.column_stack([df_test[col].astype(str).str.contains("morale", na=False) for col in df_test])
morale=df_test.loc[morale.any(axis=1)]
morale
# Out:
#      What is working well that we need to make sure to keep doing?  \
# 36                        ERGS, supporting team morale.
# 65    Within billing department, adjusted workflows ...
# 81    Keep encouraging people to get promoted from w...
# 92    Communicating the direction and decisions bein...
# 159   Keep empowering the company employees to be th...
# 167   Even just hearing that the company is trying t...
# 340   I like the frequent meeting pulses; I think he...
# 608   I'm catching up, recently submitted a morale r...
# 636   At the ground level, we have really good devel...
# 661   My team morale is great and we have one anothe...
# 744   I am thrilled to have hit my 1 year mark, so m...
# 776   I really appreciate the transparency on all le...
# 843   The recent positivity and in meeting pulse que...
# 844                Communication and full transparency!
# 892   Great colleagues, great morale, everybody ther...
# 931   I think the upper management of the company do...
# ...

# %%
relationship = np.column_stack([df_test[col].astype(str).str.contains("relationship", na=False) for col in df_test])
relationship=df_test.loc[relationship.any(axis=1)]
relationship
# Out:
#      What is working well that we need to make sure to keep doing?  \
# 407   the company is open and transparent with the o...
# 902   I feel like the check in meetings are a nice w...
# 958   The open and honest transparency of new endeav...
# 1204  Motivating employees and keeping client relati...
#
#      What is not working well and how can we do better?    ID
# 407   I think salary cuts were hard and then decreas...   408
# 902                                                 NaN   903
# 958   I feel that more can be put into making sure t...   959
# 1204  Client access is not the easiest and every par...  1205

# %%
friend = np.column_stack([df_test[col].astype(str).str.contains("friend", na=False) for col in df_test])
friend=df_test.loc[friend.any(axis=1)]
friend
# Out:
#      What is working well that we need to make sure to keep doing?  \
# 793   The many tools the Sales force has to use and ...
# 1196  keep making this workplace full of driven and ...
#
#      What is not working well and how can we do better?    ID
# 793   I think we could be more user-friendly to pati...   794
# 1196  put more hands on the project that is in top p...  1197

# %%
support = np.column_stack([df_test[col].astype(str).str.contains("support", na=False) for col in df_test])
support= df_test.loc[support.any(axis=1)]
support
# Out:
#      What is working well that we need to make sure to keep doing?  \
# 7     We need more resources in the INTL team and I'...
# 20          Communication, communication, transparency.
# 36                        ERGS, supporting team morale.
# 37    We are doing a wonderful job and staying compe...
# 43                       Continue to hire great people!
# ...                                                 ...
# 1313  Keep allowing cross team improvement. Sometime...
# 1321  Communication and listening. Like i said above...
# 1345                       s___'s support and attitude.
# 1348  I am lucky to have a supportive team and lead,...
# 1366  I think the company is really trying to suppor...
#
#      What is not working well and how can we do better?    ID
# 7     I personally am starting to feel a level of ex...     8
# 20    For re-orgs, there needs to be more support/gu...    21
# 36    Providing more of the 'black box' of _(HRIS sy...    37
# ...

# %%
remote = np.column_stack([df_test[col].astype(str).str.contains("remote", na=False) for col in df_test])
remote=df_test.loc[remote.any(axis=1)]
remote
# Out:
#      What is working well that we need to make sure to keep doing?  \
# 135                 remote teams are working seamlessly
# 185   Continue community table talks and providing r...
# 639   Continue to emphasize the value of transparenc...
# 664   Making remote people feel like 1st class citiz...
# 680                                                 NaN
# 742   the company is clearly putting in a ton of eff...
# 746                                 remote work support
# 816   Communication is good, especially as we are mo...
# 1027  adapting to the remote work requirements 2020 ...
# 1173  Extremely flexible about allowing employees to...
#
#      What is not working well and how can we do better?    ID
# 135   Company feels less academic and more productio...   136
# 185                                                 NaN   186
# 639   The sales team is not trained or resourced to ...   640
# 664                                                 NaN   665
# ...

# %%
culture = np.column_stack([df_test[col].astype(str).str.contains("culture", na=False) for col in df_test])
culture= df_test.loc[culture.any(axis=1)]
culture
# Out:
#      What is working well that we need to make sure to keep doing?  \
# 26    I appreciate the extra resources provided duri...
# 38    I love the culture, I love what I do and I lov...
# 67    Overall direction of the company is ambitious ...
# 124   Transparency, Wed. check-in, letting us know t...
# 133   Overall company culture is very good. Please k...
# 209   We are constantly striving to be better than w...
# 257   The company culture is great on certain teams....
# 280   I think we are very adaptable and willing to g...
# 283   The adulting process and 'take the time you ne...
# 294   As always, culture, transparency, communicatio...
# 299   We have great individuals who are committed to...
# 313   Keeping the culture of trust and teamwork. Com...
# 362   I really like how open the company has been to...
# 386   Continue caring about our culture and holding ...
# 420                     Data-driven business decisions.
# 461   Keep fostering a culture that reinforces that ...
# ...

# %%
satisfaction = np.column_stack([df_test[col].astype(str).str.contains("satisfaction", na=False) for col in df_test])
satisfaction= df_test.loc[satisfaction.any(axis=1)]
satisfaction
# Out:
#     What is working well that we need to make sure to keep doing?  \
# 124  Transparency, Wed. check-in, letting us know t...
# 464  Growing the business with focus on patient/cli...
# 869  putting the patient first, caring about qualit...
#
#     What is not working well and how can we do better?   ID
# 124  Computer bugs! We have to fix our ongoing IT i...  125
# 464  Maintaining software systems, educational reso...  465
# 869  Improve employee recognition. It is nice for y...  870

# %%
leadership = np.column_stack([df_test[col].astype(str).str.contains("leadership", na=False) for col in df_test])
leadership= df_test.loc[leadership.any(axis=1)]
leadership
# Out:
#      What is working well that we need to make sure to keep doing?  \
# 177   Executive communication is raw, honest, and so...
# 322                               Support of leadership
# 354                                                 NaN
# 463   the people we hire on continue to be amazing. ...
# 485   The culture. Remove technical ability and the ...
# 544                      Openness of senior leadership.
# 678   I truly appreciate the empathy of the executiv...
# 744   I am thrilled to have hit my 1 year mark, so m...
# 780   Outstanding leadership and communication from ...
# 816   Communication is good, especially as we are mo...
# 870                                 Keep on keeping on.
# 919   Supporting the sales team i these difficult ti...
# 920   Love all the communication from leadership and...
# 949                            Focusing on the mission.
# 958   The open and honest transparency of new endeav...
# 980   Remote collaboration has become more efficient...
# ...

# %%
mental = np.column_stack([df_test[col].astype(str).str.contains("mental", na=False) for col in df_test])
mental= df_test.loc[mental.any(axis=1)]
mental
# Out:
#      What is working well that we need to make sure to keep doing?  \
# 329   I think more focus on big sprint projects with...
# 340   I like the frequent meeting pulses; I think he...
# 536   focus on employee mental health and wellness -...
# 624   Improving the breadth and quality of our offer...
# 742   the company is clearly putting in a ton of eff...
# 776   I really appreciate the transparency on all le...
# 909   Continue with surveys, webinars, tabletop talk...
# 971                                                 NaN
# 1071  It's refreshing to see leadership be available...
# 1158  Transparency and supporting our teams during t...
# 1217  I love how the company emphasizes mental healt...
# 1310  No one is at their best, and our culture at th...
# 1366  I think the company is really trying to suppor...
#
#      What is not working well and how can we do better?    ID
# 329   I would love it if we could re-open the Palo A...   330
# ...

# %%
WFH = np.column_stack([df_test[col].astype(str).str.contains("WFH", na=False) for col in df_test])
WFH= df_test.loc[WFH.any(axis=1)]
WFH
# Out:
#      What is working well that we need to make sure to keep doing?  \
# 339   The open communication is very transparent and...
# 761   I guess I hadn't been taking much time off & e...
# 909   Continue with surveys, webinars, tabletop talk...
# 1031  The ability to WFH. Especially this deep into ...
# 1366  I think the company is really trying to suppor...
#
#      What is not working well and how can we do better?    ID
# 339                                                n/a.   340
# 761   I mean there's not much to do about, safely, b...   762
# 909   Some teams are really connecting while WFH, wh...   910
# 1031  In billing, there is not a lot of follow throu...  1032
# 1366  Supporting parents could improve. Many teammat...  1367

# %%
bond = np.column_stack([df_test[col].astype(str).str.contains("bond", na=False) for col in df_test])
bond= df_test.loc[bond.any(axis=1)]
bond
# Out:
#     What is working well that we need to make sure to keep doing?  \
# 877                                      communication
#
#     What is not working well and how can we do better?   ID
# 877                                       Team bonding  878

# %%
over_work = np.column_stack([df_test[col].astype(str).str.contains("over work", na=False) for col in df_test])
over_work= df_test.loc[over_work.any(axis=1)]
over_work
# Out:
#     What is working well that we need to make sure to keep doing?  \
# 561  Continue to hire intelligent and talented huma...
#
#     What is not working well and how can we do better?   ID
# 561  Teams are overworked and struggling to cover w...  562

# %%
sentiment = np.column_stack([df_test[col].astype(str).str.contains("sentiment", na=False) for col in df_test])
sentiment= df_test.loc[sentiment.any(axis=1)]
df_sentiment=sentiment

# %%
personal = np.column_stack([df_test[col].astype(str).str.contains("personal", na=False) for col in df_test])
personal= df_test.loc[personal.any(axis=1)]
personal
# Out:
#      What is working well that we need to make sure to keep doing?  \
# 7     We need more resources in the INTL team and I'...
# 13                                                  NaN
# 197   I think that this company does take very good ...
# 215                                                 NaN
# 265   I enjoy the on-going all-hands meetings hosted...
# 338   Communicating needs (personally and profession...
# 489     Continue the mission of making science personal
# 629   Our benefits and weekly meetings create a grea...
# 742   the company is clearly putting in a ton of eff...
# 778             Providing results that can help people.
# 1005  Most things are great, this is a wonderful way...
# 1071  It's refreshing to see leadership be available...
# 1158  Transparency and supporting our teams during t...
# 1260  I’m looking forward to having more engineers o...
# 1343  Support from co-workers and communication from...
#
# ...

# %%
df_personal = personal
df_personal.shape
# Out:
# (15, 3)

# %%
under_value = np.column_stack([df_test[col].astype(str).str.contains("undervalued", na=False) for col in df_test])
under_value= df_test.loc[under_value.any(axis=1)]
df_under_value = under_value
df_under_value.shape
# Out:
# (1, 3)

# %%
burn = np.column_stack([df_test[col].astype(str).str.contains("burn", na=False) for col in df_test])
burn= df_test.loc[burn.any(axis=1)]
burn
# Out:
#      What is working well that we need to make sure to keep doing?  \
# 157   Small shark bite trainings are great and very ...
# 177   Executive communication is raw, honest, and so...
# 215                                                 NaN
# 563   I liked the recent inclusion of topics such as...
# 771                                                 NaN
# 790   Keep the ingenuity in place at the company goi...
# 1162                            Keep doing what's right
# 1196  keep making this workplace full of driven and ...
# 1343  Support from co-workers and communication from...
# 1380  The compensation for having to come in during ...
#
#      What is not working well and how can we do better?    ID
# 157   Training burnout with long bi-weekly meetings....   158
# 177   (Mostly this feedback is for s___, maybe a lit...   178
# 215   I wouldn't say there are things not working we...   216
# 563                                                 NaN   564
# ...

# %%
df_burn=burn
df_burn.head()
# Out:
#     What is working well that we need to make sure to keep doing?  \
# 157  Small shark bite trainings are great and very ...
# 177  Executive communication is raw, honest, and so...
# 215                                                NaN
# 563  I liked the recent inclusion of topics such as...
# 771                                                NaN
#
#     What is not working well and how can we do better?   ID
# 157  Training burnout with long bi-weekly meetings....  158
# 177  (Mostly this feedback is for s___, maybe a lit...  178
# 215  I wouldn't say there are things not working we...  216
# 563                                                NaN  564
# 771  I see team members, including myself, not taki...  772

# %%
merge1=pd.merge(df_burn, df_under_value,df_sentiment how='outer')

# %%
merge1
# Out:
#    What is working well that we need to make sure to keep doing?  \
# 0   Small shark bite trainings are great and very ...
# 1   Executive communication is raw, honest, and so...
# 2                                                 NaN
# 3   I liked the recent inclusion of topics such as...
# 4                                                 NaN
# 5   Keep the ingenuity in place at the company goi...
# 6                             Keep doing what's right
# 7   keep making this workplace full of driven and ...
# 8   Support from co-workers and communication from...
# 9   The compensation for having to come in during ...
# 10                      Teamwork - really great here!
#
#    What is not working well and how can we do better?    ID
# 0   Training burnout with long bi-weekly meetings....   158
# 1   (Mostly this feedback is for s___, maybe a lit...   178
# 2   I wouldn't say there are things not working we...   216
# 3                                                 NaN   564
# ...

# %%
merge2= pd.merge(merge1, df_sentiment, how='outer')

# %%
merge2
# Out:
#    What is working well that we need to make sure to keep doing?  \
# 0   Small shark bite trainings are great and very ...
# 1   Executive communication is raw, honest, and so...
# 2                                                 NaN
# 3   I liked the recent inclusion of topics such as...
# 4                                                 NaN
# 5   Keep the ingenuity in place at the company goi...
# 6                             Keep doing what's right
# 7   keep making this workplace full of driven and ...
# 8   Support from co-workers and communication from...
# 9   The compensation for having to come in during ...
# 10                      Teamwork - really great here!
# 11                                                NaN
#
#    What is not working well and how can we do better?    ID
# 0   Training burnout with long bi-weekly meetings....   158
# 1   (Mostly this feedback is for s___, maybe a lit...   178
# 2   I wouldn't say there are things not working we...   216
# ...

# %%
merge3=pd.merge(merge2, personal, how='outer')

# %%
merge3
# Out:
#    What is working well that we need to make sure to keep doing?  \
# 0   Small shark bite trainings are great and very ...
# 1   Executive communication is raw, honest, and so...
# 2                                                 NaN
# 3   I liked the recent inclusion of topics such as...
# 4                                                 NaN
# 5   Keep the ingenuity in place at the company goi...
# 6                             Keep doing what's right
# 7   keep making this workplace full of driven and ...
# 8   Support from co-workers and communication from...
# 9   The compensation for having to come in during ...
# 10                      Teamwork - really great here!
# 11                                                NaN
# 12  We need more resources in the INTL team and I'...
# 13                                                NaN
# 14  I think that this company does take very good ...
# 15  I enjoy the on-going all-hands meetings hosted...
# ...

# %%
merge4=pd.merge(merge3, support, how='outer')

# %%
merge5=pd.merge(merge4, over_work, how='outer')

# %%
merge6=pd.merge(merge5, bond, how='outer')

# %%
merge7=pd.merge(merge6, communication, how='outer')

# %%
merge8=pd.merge(merge7, relationship, how='outer')

# %%
merge9=pd.merge(merge8, WFH, how='outer')

# %%
merge10=pd.merge(merge9, mental, how='outer')

# %%
merge11 =pd.merge(merge10, stress, how='outer')
merge11.shape
# Out:
# (221, 3)

# %%
merge12 =pd.merge(merge11, pressure, how='outer')

# %%
merge13 =pd.merge(merge12, friend, how='outer')

# %%
merge13.
# Out:
#   What is working well that we need to make sure to keep doing?  \
# 0  Small shark bite trainings are great and very ...
# 1  Executive communication is raw, honest, and so...
# 2                                                NaN
# 3  I liked the recent inclusion of topics such as...
# 4                                                NaN
#
#   What is not working well and how can we do better?   ID
# 0  Training burnout with long bi-weekly meetings....  158
# 1  (Mostly this feedback is for s___, maybe a lit...  178
# 2  I wouldn't say there are things not working we...  216
# 3                                                NaN  564
# 4  I see team members, including myself, not taki...  772

# %%
merge13.to_csv('Coding Data.csv')
